# %% [markdown]
# will outline how to build a classification model to predict which patients are at risk for 30-day unplanned readmission utilizing free-text hospital discharge summaries.

# %%
import pandas as pd

# %%
df=pd.read_csv("Veterans_Health_Administration_Readmissions_and_Deaths_Data.csv")
df.head()
# Out:
#   Provider_ID                                 VHA Facility  \
# 0      10009F                  BAY PINES VA MEDICAL CENTER
# 1      10009F                  BAY PINES VA MEDICAL CENTER
# 2      17008F                    WICHITA VA MEDICAL CENTER
# 3      17008F                    WICHITA VA MEDICAL CENTER
# 4      21010F  VA MARYLAND HEALTHCARE SYSTEM - PERRY POINT
#
#                  Address         City State  Zip Code    County  \
# 0  10000 BAY PINES BLVD.    BAY PINES    FL     33744  PINELLAS
# 1  10000 BAY PINES BLVD.    BAY PINES    FL     33744  PINELLAS
# 2         5500 E. KELLOG      WICHITA    KS     67218  SEDGWICK
# 3         5500 E. KELLOG      WICHITA    KS     67218  SEDGWICK
# 4      VA MEDICAL CENTER  PERRY POINT    MD     21902     CECIL
#
#                                         Measure Name     Measure ID  \
# 0  Death rate for chronic obstructive pulmonary d...   MORT-30-COPD
# 1  Rate of readmission for chronic obstructive pu...  READM-30-COPD
# ...
