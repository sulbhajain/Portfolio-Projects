# %%
#ref: https://towardsdatascience.com/explaining-feature-importance-by-example-of-a-random-forest-d9166011959e
#https://github.com/erykml/medium_articles/blob/master/feature_importance.ipynb

# %%
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
boston = load_boston()

# %%
data = pd.DataFrame(boston.data,columns = boston.feature_names)

# %%
Y = boston.target

# %%
np.random.seed(seed=42)
data['random'] = np.random.random(size=len(data))

# %%
plt.scatter(data['random'],Y)
plt.xlabel('random')
plt.ylabel('target')
plt.show()

# %%
sns.heatmap( data.corr())

# %%
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1,oob_score=True, bootstrap=True, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size =0.33, random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
print('R^2 Training Score: {:.2f} \nOOB Score: {:.2f} \nR^2 Validation Score: {:.2f}'.format(rf.score(X_train, y_train),
                                                                                             rf.oob_score_,
                                                                                             rf.score(X_test, y_test)))
# Out:
# R^2 Training Score: 0.98
# OOB Score: 0.84
# R^2 Validation Score: 0.86

# %% [markdown]
# I set a random_state to ensure results comparability. I also use bootstrap and set oob_score = True so I could later use the out-of-bag error.
#
# Briefly on the subject of out-of-bag error, each tree in the Random Forest is trained on a different dataset, sampled with replacement from the original data. This results in around ~2/3 of distinct observations in each training set. The out-of-bag error is calculated on all the observations, but for calculating each row’s error the model only considers trees which have not seen this row during training. This is similar to evaluating the model on a validation set.

# %% [markdown]
# Well, there is some overfitting in the model, as it performs much worse on OOB sample and worse on the validation set. But let’s say it is good enough and move forward to feature importances (measured on the training set performance). Some of the approaches can also be used for validation/OOB sets, to gain further interpretability on the unseen data.

# %%
plt.bar(data.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 14 artists>
