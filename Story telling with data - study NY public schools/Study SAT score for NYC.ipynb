# %%
import pandas as pd
import numpy as np

# %%
files = ["ap_2010.csv", "class_size.csv", "demographics.csv", "graduation.csv", "hs_directory.csv", "math_test_results.csv", "sat_results.csv"]

file_dict = {}

for f in files:
    #fname = "data\" + f.format
   # d = pd.read_csv("data\{0}".format(f))
   # file_dict[f.replace(".csv","")] = d
    f_name = "data/{0}".format(f)
    print(f_name)
    d = pd.read_csv(f_name)
    file_dict[f.replace(".csv", "")] = d
# Out:
# data/ap_2010.csv
# data/class_size.csv
# data/demographics.csv
# data/graduation.csv
# data/hs_directory.csv
# data/math_test_results.csv
# data/sat_results.csv

# %%
#prit header for each file
for k,v in file_dict.items():
    print("file name is \n",k)
    print(v.head())
# Out:
# file name is
#  ap_2010
#       DBN                             SchoolName AP Test Takers   \
# 0  01M448           UNIVERSITY NEIGHBORHOOD H.S.              39
# 1  01M450                 EAST SIDE COMMUNITY HS              19
# 2  01M515                    LOWER EASTSIDE PREP              24
# 3  01M539         NEW EXPLORATIONS SCI,TECH,MATH             255
# 4  02M296  High School of Hospitality Management               s
#
#   Total Exams Taken Number of Exams with scores 3 4 or 5
# 0                49                                   10
# 1                21                                    s
# 2                26                                   24
# 3               377                                  191
# 4                 s                                    s
# file name is
#  class_size
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# ...

# %%
file_dict["demographics"]["DBN"].head()
# Out:
# 0    01M015
# 1    01M015
# 2    01M015
# 3    01M015
# 4    01M015
# Name: DBN, dtype: object

# %%
file_dict["class_size"].head()
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
# 2    1       M        M015  P.S. 015 Roberto Clemente     01       GEN ED
# 3    1       M        M015  P.S. 015 Roberto Clemente     01          CTT
# 4    1       M        M015  P.S. 015 Roberto Clemente     02       GEN ED
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
# 2                                    -                                   -
# 3                                    -                                   -
# 4                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# ...

# %%
file_dict["class_size"]["DBN"] = file_dict["class_size"].apply(lambda x: "{0:02d}{1}".format(x["CSD"], x["SCHOOL CODE"]), axis=1)
#file_dict["hs_directory"]["DBN"] = file_dict["hs_directory"]["dbn"]

# %%
survey = pd.read_csv("data/survey_results.csv")

# %%
survey.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
#survey["DBN"] = survey["dbn"]
#survey_fields = ["DBN", "rr_s", "rr_t", "rr_p", "N_s", "N_t", "N_p", "saf_p_11", "com_p_11", "eng_p_11", "aca_p_11", "saf_t_11", "com_t_11", "eng_t_10", "aca_t_11", "saf_s_11", "com_s_11", "eng_s_11", "aca_s_11", "saf_tot_11", "com_tot_11", "eng_tot_11", "aca_tot_11",]
#survey = survey.loc[:,survey_fields]
#data["survey"] = survey
#survey.shape

# %%
file_dict["class_size"].head()
# there are multiple rows with same DBN
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
# 2    1       M        M015  P.S. 015 Roberto Clemente     01       GEN ED
# 3    1       M        M015  P.S. 015 Roberto Clemente     01          CTT
# 4    1       M        M015  P.S. 015 Roberto Clemente     02       GEN ED
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
# 2                                    -                                   -
# 3                                    -                                   -
# 4                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# ...

# %%
file_dict["sat_results"].head()
# Out:
#       DBN                                     School Name  \
# 0  01M292  Henry Street School for International Studies
# 1  01M448            University Neighborhood High School
# 2  01M450                East Side Community High School
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#   Number of Test Takers Critical Reading Mean Mathematics Mean Writing Mean
# 0                    31                   391              425          385
# 1                    60                   394              419          387
# 2                    69                   418              431          402
# 3                    26                   385              370          378
# 4                     s                     s                s            s

# %%
class_size = file_dict["class_size"]
class_size = class_size[class_size["GRADE "]=="09-12"]
class_size = class_size[class_size["PROGRAM TYPE"] == "GEN ED"]

# %%
class_size.head()
# Out:
#      CSD BOROUGH SCHOOL CODE                                    SCHOOL NAME  \
# 225    1       M        M292  Henry Street School for International Studies
# 226    1       M        M292  Henry Street School for International Studies
# 227    1       M        M292  Henry Street School for International Studies
# 228    1       M        M292  Henry Street School for International Studies
# 229    1       M        M292  Henry Street School for International Studies
#
#     GRADE  PROGRAM TYPE CORE SUBJECT (MS CORE and 9-12 ONLY)  \
# 225  09-12       GEN ED                              ENGLISH
# 226  09-12       GEN ED                              ENGLISH
# 227  09-12       GEN ED                              ENGLISH
# 228  09-12       GEN ED                              ENGLISH
# 229  09-12       GEN ED                                 MATH
#
#     CORE COURSE (MS CORE and 9-12 ONLY) SERVICE CATEGORY(K-9* ONLY)  \
# 225                           English 9                           -
# ...

# %%
class_size = class_size.groupby("DBN").agg(np.mean)

# %%
class_size.head()
# Out:
#         CSD  NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# DBN
# 01M292    1                            88.0000            4.000000
# 01M332    1                            46.0000            2.000000
# 01M378    1                            33.0000            1.000000
# 01M448    1                           105.6875            4.750000
# 01M450    1                            57.6000            2.733333
#
#         AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# DBN
# 01M292           22.564286                   18.50              26.571429
# 01M332           22.000000                   21.00              23.500000
# 01M378           33.000000                   33.00              33.000000
# 01M448           22.231250                   18.25              27.062500
# 01M450           21.200000                   19.40              22.866667
#
#         SCHOOLWIDE PUPIL-TEACHER RATIO
# DBN
# 01M292                             NaN
# ...

# %%
class_size.reset_index(inplace=True)
file_dict["class_size"] = class_size

# %%
class_size.head()
# Out:
#       DBN  CSD  NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# 0  01M292    1                            88.0000            4.000000
# 1  01M332    1                            46.0000            2.000000
# 2  01M378    1                            33.0000            1.000000
# 3  01M448    1                           105.6875            4.750000
# 4  01M450    1                            57.6000            2.733333
#
#    AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# 0           22.564286                   18.50              26.571429
# 1           22.000000                   21.00              23.500000
# 2           33.000000                   33.00              33.000000
# 3           22.231250                   18.25              27.062500
# 4           21.200000                   19.40              22.866667
#
#    SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                             NaN
# 1                             NaN
# ...

# %%
demo = file_dict["demographics"]

# %%
demo.head()
# Out:
#       DBN                       Name  schoolyear fl_percent  frl_percent  \
# 0  01M015  P.S. 015 ROBERTO CLEMENTE    20052006       89.4          NaN
# 1  01M015  P.S. 015 ROBERTO CLEMENTE    20062007       89.4          NaN
# 2  01M015  P.S. 015 ROBERTO CLEMENTE    20072008       89.4          NaN
# 3  01M015  P.S. 015 ROBERTO CLEMENTE    20082009       89.4          NaN
# 4  01M015  P.S. 015 ROBERTO CLEMENTE    20092010                    96.5
#
#    total_enrollment prek   k grade1 grade2    ...     black_num black_per  \
# 0               281   15  36     40     33    ...            74      26.3
# 1               243   15  29     39     38    ...            68      28.0
# 2               261   18  43     39     36    ...            77      29.5
# 3               252   17  37     44     32    ...            75      29.8
# 4               208   16  40     28     32    ...            67      32.2
#
#   hispanic_num hispanic_per white_num white_per male_num male_per female_num  \
# ...

# %%
demo = demo[demo["schoolyear"]==20112012]

# %%
demo.head()
# Out:
#        DBN                                              Name  schoolyear  \
# 6   01M015  P.S. 015 ROBERTO CLEMENTE                           20112012
# 13  01M019  P.S. 019 ASHER LEVY                                 20112012
# 20  01M020  PS 020 ANNA SILVER                                  20112012
# 27  01M034  PS 034 FRANKLIN D ROOSEVELT                         20112012
# 35  01M063  PS 063 WILLIAM MCKINLEY                             20112012
#
#    fl_percent  frl_percent  total_enrollment prek    k grade1 grade2  \
# 6         NaN         89.4               189   13   31     35     28
# 13        NaN         61.5               328   32   46     52     54
# 20        NaN         92.5               626   52  102    121     87
# 27        NaN         99.7               401   14   34     38     36
# 35        NaN         78.9               176   18   20     30     21
#
#       ...     black_num black_per hispanic_num hispanic_per white_num  \
# ...

# %%
file_dict["demographics"] = demo

# %%
maths = file_dict["math_test_results"]

# %%
maths.head()
# Out:
#       DBN Grade  Year      Category  Number Tested Mean Scale Score Level 1 #  \
# 0  01M015     3  2006  All Students             39              667         2
# 1  01M015     3  2007  All Students             31              672         2
# 2  01M015     3  2008  All Students             37              668         0
# 3  01M015     3  2009  All Students             33              668         0
# 4  01M015     3  2010  All Students             26              677         6
#
#   Level 1 % Level 2 # Level 2 % Level 3 # Level 3 % Level 4 # Level 4 %  \
# 0      5.1%        11     28.2%        20     51.3%         6     15.4%
# 1      6.5%         3      9.7%        22       71%         4     12.9%
# 2        0%         6     16.2%        29     78.4%         2      5.4%
# 3        0%         4     12.1%        28     84.8%         1        3%
# 4     23.1%        12     46.2%         6     23.1%         2      7.7%
#
#   Level 3+4 # Level 3+4 %
# 0          26       66.7%
# ...

# %%
maths = maths[maths['Grade']=='8']

# %%
maths = maths[maths['Year']==2011]

# %%
maths.head()
# Out:
#         DBN Grade  Year      Category  Number Tested Mean Scale Score  \
# 111  01M034     8  2011  All Students             48              646
# 280  01M140     8  2011  All Students             61              665
# 346  01M184     8  2011  All Students             49              727
# 388  01M188     8  2011  All Students             49              658
# 411  01M292     8  2011  All Students             49              650
#
#     Level 1 # Level 1 % Level 2 # Level 2 % Level 3 # Level 3 % Level 4 #  \
# 111        15     31.3%        22     45.8%        11     22.9%         0
# 280         1      1.6%        43     70.5%        17     27.9%         0
# 346         0        0%         0        0%         5     10.2%        44
# 388        10     20.4%        26     53.1%        10     20.4%         3
# 411        15     30.6%        25       51%         7     14.3%         2
#
#     Level 4 % Level 3+4 # Level 3+4 %
# 111        0%          11       22.9%
# ...

# %%
maths['Grade']
# Out:
# 111      8
# 280      8
# 346      8
# 388      8
# 411      8
# 433      8
# 482      8
# 503      8
# 590      8
# 610      8
# 651      8
# 674      8
# 1010     8
# 1052     8
# 1075     8
# 1165     8
# 1213     8
# 1285     8
# 1399     8
# 1441     8
# 1489     8
# 1513     8
# 1539     8
# 1588     8
# 1622     8
# 1646     8
# 1670     8
# 1694     8
# 1735     8
# 1758     8
#         ..
# 27010    8
# 27050    8
# 27078    8
# 27153    8
# 27195    8
# 27315    8
# 27373    8
# 27428    8
# 27468    8
# 27510    8
# 27581    8
# 27653    8
# 27694    8
# 27736    8
# 27775    8
# 27816    8
# 27855    8
# 27923    8
# 27959    8
# 28001    8
# 28043    8
# 28138    8
# 28205    8
# 28247    8
# 28286    8
# 28328    8
# 28369    8
# 28405    8
# 28430    8
# 28471    8
# Name: Grade, Length: 499, dtype: object

# %%
 file_dict["math_test_results"] = maths

# %%
file_dict["graduation"] = file_dict["graduation"][file_dict["graduation"]["Cohort"] == "2006"]
file_dict["graduation"] = file_dict["graduation"][file_dict["graduation"]["Demographic"] == "Total Cohort"]

# %%
file_dict["sat_results"].head()
# Out:
#       DBN                                     School Name  \
# 0  01M292  Henry Street School for International Studies
# 1  01M448            University Neighborhood High School
# 2  01M450                East Side Community High School
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#   Number of Test Takers Critical Reading Mean Mathematics Mean Writing Mean
# 0                    31                   391              425          385
# 1                    60                   394              419          387
# 2                    69                   418              431          402
# 3                    26                   385              370          378
# 4                     s                     s                s            s

# %%
file_dict["sat_results"]["Critical Reading Mean"]
# Out:
# 0      391
# 1      394
# 2      418
# 3      385
# 4        s
# 5      314
# 6      568
# 7      411
# 8      630
# 9      405
# 10     422
# 11     382
# 12     397
# 13     424
# 14     405
# 15     381
# 16     411
# 17     409
# 18     421
# 19     401
# 20     395
# 21       s
# 22     465
# 23     484
# 24     495
# 25     523
# 26     561
# 27     475
# 28     454
# 29     555
#       ...
# 430    343
# 431    502
# 432    560
# 433      s
# 434    508
# 435    431
# 436    437
# 437    439
# 438    459
# 439    463
# 440    474
# 441    411
# 442    638
# 443    382
# 444      s
# 445    389
# 446    363
# 447    355
# 448    394
# 449    357
# 450      s
# 451      s
# 452      s
# 453      s
# 454      s
# 455    407
# 456      s
# 457      s
# 458    390
# 459    404
# Name: Critical Reading Mean, Length: 460, dtype: object

# %%
cols = ["Critical Reading Mean", "Mathematics Mean","Writing Mean"]
for c in cols:
    file_dict["sat_results"][c] = file_dict["sat_results"][c].convert_objects(convert_numeric=True)

file_dict['sat_results']['sat_score'] = file_dict['sat_results'][cols[0]] + file_dict['sat_results'][cols[1]] + file_dict['sat_results'][cols[2]]
# Out:
# /Users/sulbha/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
file_dict['sat_results'].head()
# Out:
#       DBN                                     School Name  \
# 0  01M292  Henry Street School for International Studies
# 1  01M448            University Neighborhood High School
# 2  01M450                East Side Community High School
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#   Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                    31                  391.0             425.0
# 1                    60                  394.0             419.0
# 2                    69                  418.0             431.0
# 3                    26                  385.0             370.0
# 4                     s                    NaN               NaN
#
#    Writing Mean  sat_score
# 0         385.0     1201.0
# 1         387.0     1200.0
# 2         402.0     1251.0
# 3         378.0     1133.0
# 4           NaN        NaN

# %%
#file_dict["hs_directory"]['lat'] = file_dict["hs_directory"]['Location 1'].apply(lambda x: x.split("\n")[-1].replace("(", "").replace(")", "").split(", ")[0])
#data["hs_directory"]['lon'] = data["hs_directory"]['Location 1'].apply(lambda x: x.split("\n")[-1].replace("(", "").replace(")", "").split(", ")[1])

# %%
#for c in ['lat', 'lon']:
#    data["hs_directory"][c] = data["hs_directory"][c].convert_objects(convert_numeric=True)

# %%
for k,v in file_dict.items():
    print(k)
    print(v.head())
# Out:
# ap_2010
#       DBN                             SchoolName AP Test Takers   \
# 0  01M448           UNIVERSITY NEIGHBORHOOD H.S.              39
# 1  01M450                 EAST SIDE COMMUNITY HS              19
# 2  01M515                    LOWER EASTSIDE PREP              24
# 3  01M539         NEW EXPLORATIONS SCI,TECH,MATH             255
# 4  02M296  High School of Hospitality Management               s
#
#   Total Exams Taken Number of Exams with scores 3 4 or 5
# 0                49                                   10
# 1                21                                    s
# 2                26                                   24
# 3               377                                  191
# 4                 s                                    s
# class_size
#       DBN  CSD  NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# 0  01M292    1                            88.0000            4.000000
# ...

# %%
flat_data_names = [k for k,v in file_dict.items()]
flat_data = [file_dict[k] for k in flat_data_names]

# %%
print(flat_data[1])
# Out:
#         DBN  CSD  NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# 0    01M292    1                          88.000000            4.000000
# 1    01M332    1                          46.000000            2.000000
# 2    01M378    1                          33.000000            1.000000
# 3    01M448    1                         105.687500            4.750000
# 4    01M450    1                          57.600000            2.733333
# 5    01M458    1                          28.600000            1.200000
# 6    01M509    1                          69.642857            3.000000
# 7    01M515    1                         131.117647            5.529412
# 8    01M539    1                         156.368421            6.157895
# 9    01M650    1                          64.125000            2.937500
# 10   01M696    1                         214.166667           10.250000
# 11   02M047    2                          26.818182            1.636364
# ...

# %%
print(file_dict["hs_directory"].head())
# Out:
#   DBN\tschool_name\tborough\tbuilding_code\tphone_number\tfax_number\tgrade_span_min\tgrade_span_max\texpgrade_span_min\texpgrade_span_max\tbus\tsubway\tprimary_address_line_1\tcity\tstate_code\tpostcode\twebsite\ttotal_students\tcampus_name\tschool_type\toverview_paragraph\tprogram_highlights\tlanguage_classes\tadvancedplacement_courses\tonline_ap_courses\tonline_language_courses\textracurricular_activities\tpsal_sports_boys\tpsal_sports_girls\tpsal_sports_coed\tschool_sports\tpartner_cbo\tpartner_hospital\tpartner_highered\tpartner_cultural\tpartner_nonprofit\tpartner_corporate\tpartner_financial\tpartner_other\taddtl_info1\taddtl_info2\tstart_time\tend_time\tse_services\tell_programs\tschool_accessibility_description\tnumber_programs\tpriority01\tpriority02\tpriority03\tpriority04\tpriority05\tpriority06\tpriority07\tpriority08\tpriority09\tpriority10\tLocation 1\tCommunity Board\tCouncil District\tCensus Tract\tBIN\tBBL\tNTA\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t
# ...

# %%
full = flat_data[0]
for i, f in enumerate(flat_data[1:]):
    name = flat_data_names[i+1]
    print(name)
    if name != "hs_directory":
        print(len(f["DBN"]) - len(f["DBN"].unique()))
        join_type = "inner"
        if name in ["sat_results", "ap_2010", "graduation"]:
            join_type = "outer"
        if name not in ["math_test_results"]:
            full = full.merge(f, on="DBN", how=join_type)

full.shape
# Out:
# class_size
# 0
# demographics
# 0
# graduation
# 0
# hs_directory
# math_test_results
# 0
# sat_results
# 2
# (472, 77)

# %%
full.head()
# Out:
#       DBN                             SchoolName AP Test Takers   \
# 0  01M448           UNIVERSITY NEIGHBORHOOD H.S.              39
# 1  01M450                 EAST SIDE COMMUNITY HS              19
# 2  01M515                    LOWER EASTSIDE PREP              24
# 3  01M539         NEW EXPLORATIONS SCI,TECH,MATH             255
# 4  02M296  High School of Hospitality Management               s
#
#   Total Exams Taken Number of Exams with scores 3 4 or 5  CSD  \
# 0                49                                   10  1.0
# 1                21                                    s  1.0
# 2                26                                   24  1.0
# 3               377                                  191  1.0
# 4                 s                                    s  2.0
#
#    NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# 0                         105.687500            4.750000           22.231250
# ...

# %%
cols = ['AP Test Takers ', 'Total Exams Taken', 'Number of Exams with scores 3 4 or 5']

for col in cols:
    full[col] = full[col].convert_objects(convert_numeric=True)

full[cols] = full[cols].fillna(value=0)
# Out:
# /Users/sulbha/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.

# %%
full["school_dist"] = full["DBN"].apply(lambda x: x[:2])

# %%
full = full.fillna(full.mean())

# %%
full.head()
# Out:
#       DBN                             SchoolName  AP Test Takers   \
# 0  01M448           UNIVERSITY NEIGHBORHOOD H.S.             39.0
# 1  01M450                 EAST SIDE COMMUNITY HS             19.0
# 2  01M515                    LOWER EASTSIDE PREP             24.0
# 3  01M539         NEW EXPLORATIONS SCI,TECH,MATH            255.0
# 4  02M296  High School of Hospitality Management              0.0
#
#    Total Exams Taken  Number of Exams with scores 3 4 or 5  CSD  \
# 0               49.0                                  10.0  1.0
# 1               21.0                                   0.0  1.0
# 2               26.0                                  24.0  1.0
# 3              377.0                                 191.0  1.0
# 4                0.0                                   0.0  2.0
#
#    NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# 0                         105.687500            4.750000           22.231250
# ...

# %%
full.corr()['sat_score']
# Out:
# AP Test Takers                          0.577106
# Total Exams Taken                       0.564887
# Number of Exams with scores 3 4 or 5    0.564879
# CSD                                     0.055306
# NUMBER OF STUDENTS / SEATS FILLED       0.326285
# NUMBER OF SECTIONS                      0.296617
# AVERAGE CLASS SIZE                      0.371300
# SIZE OF SMALLEST CLASS                  0.303956
# SIZE OF LARGEST CLASS                   0.267317
# SCHOOLWIDE PUPIL-TEACHER RATIO               NaN
# schoolyear                                   NaN
# frl_percent                            -0.629206
# total_enrollment                        0.311325
# ell_num                                -0.102624
# ell_percent                            -0.277641
# sped_num                                0.005493
# sped_percent                           -0.458841
# asian_num                               0.422403
# asian_per                               0.522704
# ...

# %%
# %matplotlib inline

full.plot.scatter(x='total_enrollment', y='sat_score')

# %%
full[(full["total_enrollment"] < 1000) & (full["sat_score"] < 1000)]["School Name_y"]
# Out:
# 105             Kingsbridge International High School
# 107              International School of Liberal Arts
# 136              Fannie Lou Hamer Freedom High School
# 295               INTERNATIONAL COMMUNITY HIGH SCHOOL
# 330                     HIGH SCHOOL OF WORLD CULTURES
# 337    Brooklyn High Sch for Leadership Community Svc
# 356           International High School @Prospect Hgt
# Name: School Name_y, dtype: object

# %%
full.plot.scatter(x='ell_percent', y='sat_score')

# %%
full.corr()["sat_score"][["asian_per", "black_per", "hispanic_per", "white_per"]]
full.corr()["sat_score"][["asian_per", "black_per", "hispanic_per", "white_per"]].plot.bar()

# %%
full.corr()["sat_score"][["male_per", "female_per"]]
# Out:
# male_per     -0.097924
# female_per    0.097935
# Name: sat_score, dtype: float64

# %%
full.corr()["sat_score"][["male_per", "female_per"]].plot.bar()

# %%
full.plot.scatter(x='female_per', y='sat_score')

# %%
#schools performing high SAT scores for females
full[(full["female_per"] > 65) & (full["sat_score"] > 1400)]["School Name_y"]
# Out:
# 11                Professional Performng Arts School
# 15                     ELEANOR ROOSEVELT HIGH SCHOOL
# 43                      LAGUARDIA HIGH SCH MUSIC ART
# 210    Townsend Harris High School at Queens College
# 239                 Frank Sinatra School of the Arts
# Name: School Name_y, dtype: object

# %%
full["ap_avg"] = full["AP Test Takers "] / full["total_enrollment"]

full.plot.scatter(x='ap_avg', y='sat_score')

# %%
full[(full["ap_avg"] > .3) & (full["sat_score"] > 1700)]["School Name_y"]
# Out:
# 15                     ELEANOR ROOSEVELT HIGH SCHOOL
# 24                            STUYVESANT HIGH SCHOOL
# 116                     BRONX HIGH SCHOOL OF SCIENCE
# 121         HS of American Studies at Lehman College
# 142                   BROOKLYN TECHNICAL HIGH SCHOOL
# 210    Townsend Harris High School at Queens College
# 228                   QUEENS HS FOR SCIENCE YORK COL
# 250              STATEN ISLAND TECHNICAL HIGH SCHOOL
# Name: School Name_y, dtype: object
