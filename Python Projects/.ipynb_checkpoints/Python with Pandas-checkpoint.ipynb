# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.DS_Store', '.ipynb_checkpoints', 'Python with Pandas.ipynb', 'Data']

# %%
data = pd.read_csv("data/supermarkets.csv")
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data = pd.read_json("data/supermarkets.json")
data
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
data = pd.read_excel("data/supermarkets.xlsx")
data
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
data = pd.read_csv("data/supermarkets-semi-colons.txt", sep=';')
data
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data = pd.read_csv("data/supermarkets-commas.txt", sep=',', index_col=0)
data
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %% [markdown]
# ## indexxing and slicing for dataframea

# %%
data = pd.read_json("data/supermarkets.json")
data
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1 = data.set_index('Address')
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.reset_index()
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.set_index('Name', inplace = True)
df1
# Out:
#                       City Country  Employees             State
# Name
# Madeira      San Francisco     USA          8          CA 94114
# Bready Shop  San Francisco     USA         15          CA 94119
# Super River  San Francisco     USA         25  California 94114
# Ben's Shop   San Francisco     USA         10          CA 94114
# Sanchez      San Francisco     USA         12        California
# Richvalley   San Francisco     USA         20          CA 94114

# %%
# slicng 
df1.loc[:,'Country']
# Out:
# Name
# Madeira        USA
# Bready Shop    USA
# Super River    USA
# Ben's Shop     USA
# Sanchez        USA
# Richvalley     USA
# Name: Country, dtype: object

# %%
list(df1.loc[:,'Country'])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df1.iloc[1:3,:]
# Out:
#                       City Country  Employees             State
# Name
# Bready Shop  San Francisco     USA         15          CA 94119
# Super River  San Francisco     USA         25  California 94114

# %%
df1.iloc[1:3,2]
# Out:
# Name
# Bready Shop    15
# Super River    25
# Name: Employees, dtype: int64

# %%
df1.ix[1:3,'State']
# Out:
# Name
# Bready Shop            CA 94119
# Super River    California 94114
# Name: State, dtype: object

# %%
df1.columns
# Out:
# Index(['City', 'Country', 'Employees', 'State'], dtype='object')

# %%
df1.drop('Bready Shop')
# Out:
#                       City Country  Employees             State
# Name
# Madeira      San Francisco     USA          8          CA 94114
# Super River  San Francisco     USA         25  California 94114
# Ben's Shop   San Francisco     USA         10          CA 94114
# Sanchez      San Francisco     USA         12        California
# Richvalley   San Francisco     USA         20          CA 94114

# %%
# Out:
#   File "<ipython-input-39-723cc7081c8c>", line 1
#     df1.drop(df1.index(0:2))
#                         ^
# SyntaxError: invalid syntax

# %%
df1.drop(df1.index[0:2])
# Out:
#                       City Country  Employees             State
# Name
# Super River  San Francisco     USA         25  California 94114
# Ben's Shop   San Francisco     USA         10          CA 94114
# Sanchez      San Francisco     USA         12        California
# Richvalley   San Francisco     USA         20          CA 94114

# %%
df1.drop(df1.columns[0:2], axis = 1)
# Out:
#              Employees             State
# Name
# Madeira              8          CA 94114
# Bready Shop         15          CA 94119
# Super River         25  California 94114
# Ben's Shop          10          CA 94114
# Sanchez             12        California
# Richvalley          20          CA 94114

# %%
df1.index
# Out:
# Index(['Madeira', 'Bready Shop', 'Super River', 'Ben's Shop', 'Sanchez',
#        'Richvalley'],
#       dtype='object', name='Name')

# %%
# add columns to a dataframe

# %%
df1.shape
# Out:
# (6, 4)

# %%
df1['Continent'] = df1.shape[0]*['North America']
df1
# Out:
#                       City Country  Employees             State      Continent
# Name
# Madeira      San Francisco     USA          8          CA 94114  North America
# Bready Shop  San Francisco     USA         15          CA 94119  North America
# Super River  San Francisco     USA         25  California 94114  North America
# Ben's Shop   San Francisco     USA         10          CA 94114  North America
# Sanchez      San Francisco     USA         12        California  North America
# Richvalley   San Francisco     USA         20          CA 94114  North America

# %%
df1['Address'] = df1['City'] + ' ,' + df1['State']
df1
# Out:
#                       City Country  Employees             State  \
# Name
# Madeira      San Francisco     USA          8          CA 94114
# Bready Shop  San Francisco     USA         15          CA 94119
# Super River  San Francisco     USA         25  California 94114
# Ben's Shop   San Francisco     USA         10          CA 94114
# Sanchez      San Francisco     USA         12        California
# Richvalley   San Francisco     USA         20          CA 94114
#
#                  Continent                          Address
# Name
# Madeira      North America          San Francisco ,CA 94114
# Bready Shop  North America          San Francisco ,CA 94119
# Super River  North America  San Francisco ,California 94114
# Ben's Shop   North America          San Francisco ,CA 94114
# Sanchez      North America        San Francisco ,California
# Richvalley   North America          San Francisco ,CA 94114

# %%
# add a new row
df1_T = df1.T
df1_T
# Out:
# Name                       Madeira              Bready Shop  \
# City                 San Francisco            San Francisco
# Country                        USA                      USA
# Employees                        8                       15
# State                     CA 94114                 CA 94119
# Continent            North America            North America
# Address    San Francisco ,CA 94114  San Francisco ,CA 94119
#
# Name                           Super River               Ben's Shop  \
# City                         San Francisco            San Francisco
# Country                                USA                      USA
# Employees                               25                       10
# State                     California 94114                 CA 94114
# Continent                    North America            North America
# Address    San Francisco ,California 94114  San Francisco ,CA 94114
#
# Name                         Sanchez               Richvalley
# ...

# %%
df1_T['Rame'] = ['SFO', 'US', 8, 'CA', 'America', 'Amerrica']
df1_T
# Out:
# Name                       Madeira              Bready Shop  \
# City                 San Francisco            San Francisco
# Country                        USA                      USA
# Employees                        8                       15
# State                     CA 94114                 CA 94119
# Continent            North America            North America
# Address    San Francisco ,CA 94114  San Francisco ,CA 94119
#
# Name                           Super River               Ben's Shop  \
# City                         San Francisco            San Francisco
# Country                                USA                      USA
# Employees                               25                       10
# State                     California 94114                 CA 94114
# Continent                    North America            North America
# Address    San Francisco ,California 94114  San Francisco ,CA 94114
#
# ...

# %%
df2 = df1_T.T
df2
# Out:
#                       City Country Employees             State      Continent  \
# Name
# Madeira      San Francisco     USA         8          CA 94114  North America
# Bready Shop  San Francisco     USA        15          CA 94119  North America
# Super River  San Francisco     USA        25  California 94114  North America
# Ben's Shop   San Francisco     USA        10          CA 94114  North America
# Sanchez      San Francisco     USA        12        California  North America
# Richvalley   San Francisco     USA        20          CA 94114  North America
# Rame                   SFO      US         8                CA        America
#
#                                      Address
# Name
# Madeira              San Francisco ,CA 94114
# Bready Shop          San Francisco ,CA 94119
# Super River  San Francisco ,California 94114
# Ben's Shop           San Francisco ,CA 94114
# Sanchez            San Francisco ,California
# Richvalley           San Francisco ,CA 94114
# ...
